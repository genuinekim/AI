# %% [markdown]
# # 데이터 준비하기

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/pokemon_pix2pix_dataset/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 830

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# # Encoder-decoder구조의 Generator 구성하기

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,512)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 1, 512)]       0
# _________________________________________________________________
# decode_block (DecodeBlock)   (None, 2, 2, 512)         4196352
# _________________________________________________________________
# decode_block_1 (DecodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# decode_block_2 (DecodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# decode_block_3 (DecodeBlock) (None, 16, 16, 512)       4196352
# _________________________________________________________________
# decode_block_4 (DecodeBlock) (None, 32, 32, 256)       2098176
# _________________________________________________________________
# decode_block_5 (DecodeBlock) (None, 64, 64, 128)       524800
# _________________________________________________________________
# decode_block_6 (DecodeBlock) (None, 128, 128, 64)      131328
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 256, 256, 3)       3072
# =================================================================
# Total params: 19,542,784
# Trainable params: 19,537,792
# Non-trainable params: 4,992
# _________________________________________________________________

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        

EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encoder_1 (Encoder)          (None, 1, 1, 512)         19544576
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 256, 256, 3)       19542784
# =================================================================
# Total params: 39,087,360
# Trainable params: 39,076,480
# Non-trainable params: 10,880
# _________________________________________________________________

# %% [markdown]
# # U-Net구조의 Generator 구성하기

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_16 (EncodeBlock)   (None, 128, 128, 64) 3072        input_4[0][0]
# __________________________________________________________________________________________________
# encode_block_17 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_16[0][0]
# __________________________________________________________________________________________________
# encode_block_18 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_17[0][0]
# __________________________________________________________________________________________________
# encode_block_19 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_18[0][0]
# __________________________________________________________________________________________________
# encode_block_20 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_19[0][0]
# __________________________________________________________________________________________________
# encode_block_21 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_20[0][0]
# __________________________________________________________________________________________________
# encode_block_22 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_21[0][0]
# __________________________________________________________________________________________________
# encode_block_23 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_14 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_23[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block_14[0][0]
#                                                                  encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_15 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_15[0][0]
#                                                                  encode_block_21[0][0]
# __________________________________________________________________________________________________
# decode_block_16 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_16[0][0]
#                                                                  encode_block_20[0][0]
# __________________________________________________________________________________________________
# decode_block_17 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_17[0][0]
#                                                                  encode_block_19[0][0]
# __________________________________________________________________________________________________
# decode_block_18 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_18[0][0]
#                                                                  encode_block_18[0][0]
# __________________________________________________________________________________________________
# decode_block_19 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_19[0][0]
#                                                                  encode_block_17[0][0]
# __________________________________________________________________________________________________
# decode_block_20 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_20[0][0]
#                                                                  encode_block_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# # Discriminator 구현하기

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# # 학습 및 테스트

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 10

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.9275
# L1_loss:0.5100
# Discriminator_loss:1.1080
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.0634
# L1_loss:0.2919
# Discriminator_loss:1.4229
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.3188
# L1_loss:0.2580
# Discriminator_loss:1.1554
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.2221
# L1_loss:0.2185
# Discriminator_loss:0.8482
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.9458
# L1_loss:0.1934
# Discriminator_loss:1.2616
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.9454
# L1_loss:0.2142
# Discriminator_loss:0.4427
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.7834
# L1_loss:0.3053
# Discriminator_loss:0.7015
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.0597
# L1_loss:0.2314
# Discriminator_loss:0.6786
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.8314
# L1_loss:0.2382
# Discriminator_loss:0.4684
#
# EPOCH[1] - STEP[100]
# Generator_loss:0.6177
# L1_loss:0.3424
# Discriminator_loss:1.4416
#
# EPOCH[1] - STEP[110]
# Generator_loss:2.2042
# L1_loss:0.2068
# Discriminator_loss:0.8065
#
# EPOCH[1] - STEP[120]
# Generator_loss:3.0864
# L1_loss:0.2671
# Discriminator_loss:0.3439
#
# EPOCH[1] - STEP[130]
# Generator_loss:1.6015
# L1_loss:0.2668
# Discriminator_loss:0.4377
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.8063
# L1_loss:0.3497
# Discriminator_loss:0.3486
#
# EPOCH[1] - STEP[150]
# Generator_loss:1.2703
# L1_loss:0.2690
# Discriminator_loss:0.4693
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.3528
# L1_loss:0.2418
# Discriminator_loss:1.1689
#
# EPOCH[1] - STEP[170]
# Generator_loss:2.2539
# L1_loss:0.2604
# Discriminator_loss:0.2835
#
# EPOCH[1] - STEP[180]
# Generator_loss:2.5794
# L1_loss:0.2355
# Discriminator_loss:1.1827
#
# EPOCH[1] - STEP[190]
# Generator_loss:2.4158
# L1_loss:0.3184
# Discriminator_loss:0.2869
#
# EPOCH[1] - STEP[200]
# Generator_loss:3.4956
# L1_loss:0.2454
# Discriminator_loss:2.1310
#
# EPOCH[2] - STEP[10]
# Generator_loss:0.2765
# L1_loss:0.2395
# Discriminator_loss:1.6614
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.3791
# L1_loss:0.2265
# Discriminator_loss:0.4486
#
# EPOCH[2] - STEP[30]
# Generator_loss:3.1240
# L1_loss:0.2637
# Discriminator_loss:0.1974
#
# EPOCH[2] - STEP[40]
# Generator_loss:2.7280
# L1_loss:0.2360
# Discriminator_loss:0.1866
#
# EPOCH[2] - STEP[50]
# Generator_loss:1.1899
# L1_loss:0.2138
# Discriminator_loss:1.1483
#
# EPOCH[2] - STEP[60]
# Generator_loss:2.3802
# L1_loss:0.2166
# Discriminator_loss:0.4178
#
# EPOCH[2] - STEP[70]
# Generator_loss:1.1904
# L1_loss:0.2351
# Discriminator_loss:0.4748
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.5964
# L1_loss:0.2194
# Discriminator_loss:0.9531
#
# EPOCH[2] - STEP[90]
# Generator_loss:3.0169
# L1_loss:0.2667
# Discriminator_loss:0.1949
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.2920
# L1_loss:0.2545
# Discriminator_loss:0.6684
#
# EPOCH[2] - STEP[110]
# Generator_loss:2.1190
# L1_loss:0.2747
# Discriminator_loss:0.1932
#
# EPOCH[2] - STEP[120]
# Generator_loss:2.2377
# L1_loss:0.2756
# Discriminator_loss:0.2295
#
# EPOCH[2] - STEP[130]
# Generator_loss:0.8287
# L1_loss:0.2304
# Discriminator_loss:0.9578
#
# EPOCH[2] - STEP[140]
# Generator_loss:3.6529
# L1_loss:0.2706
# Discriminator_loss:0.2355
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.2392
# L1_loss:0.2563
# Discriminator_loss:0.4918
#
# EPOCH[2] - STEP[160]
# Generator_loss:2.7453
# L1_loss:0.3312
# Discriminator_loss:0.2202
#
# EPOCH[2] - STEP[170]
# Generator_loss:1.6611
# L1_loss:0.2808
# Discriminator_loss:0.9759
#
# EPOCH[2] - STEP[180]
# Generator_loss:0.6603
# L1_loss:0.2720
# Discriminator_loss:0.9898
#
# EPOCH[2] - STEP[190]
# Generator_loss:3.0922
# L1_loss:0.2689
# Discriminator_loss:0.3700
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.3571
# L1_loss:0.2123
# Discriminator_loss:1.4386
#
# EPOCH[3] - STEP[10]
# Generator_loss:3.0820
# L1_loss:0.2210
# Discriminator_loss:0.6739
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.0719
# L1_loss:0.2569
# Discriminator_loss:0.6380
#
# EPOCH[3] - STEP[30]
# Generator_loss:2.0675
# L1_loss:0.2925
# Discriminator_loss:0.2648
#
# EPOCH[3] - STEP[40]
# Generator_loss:0.5652
# L1_loss:0.2315
# Discriminator_loss:1.2897
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.6316
# L1_loss:0.2549
# Discriminator_loss:0.3211
#
# EPOCH[3] - STEP[60]
# Generator_loss:1.8695
# L1_loss:0.2598
# Discriminator_loss:0.4214
#
# EPOCH[3] - STEP[70]
# Generator_loss:2.3794
# L1_loss:0.2284
# Discriminator_loss:2.4013
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.4913
# L1_loss:0.3101
# Discriminator_loss:0.3250
#
# EPOCH[3] - STEP[90]
# Generator_loss:2.8678
# L1_loss:0.3116
# Discriminator_loss:0.2091
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.4214
# L1_loss:0.3870
# Discriminator_loss:0.3440
#
# EPOCH[3] - STEP[110]
# Generator_loss:0.2091
# L1_loss:0.2234
# Discriminator_loss:1.8839
#
# EPOCH[3] - STEP[120]
# Generator_loss:2.3870
# L1_loss:0.2546
# Discriminator_loss:0.5907
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.6640
# L1_loss:0.2842
# Discriminator_loss:0.3307
#
# EPOCH[3] - STEP[140]
# Generator_loss:0.3696
# L1_loss:0.2221
# Discriminator_loss:1.6932
#
# EPOCH[3] - STEP[150]
# Generator_loss:2.2133
# L1_loss:0.2327
# Discriminator_loss:0.8976
#
# EPOCH[3] - STEP[160]
# Generator_loss:0.4554
# L1_loss:0.2323
# Discriminator_loss:1.2920
# EPOCH[3] - STEP[170]
# Generator_loss:2.3561
# L1_loss:0.2676
# Discriminator_loss:0.4375
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.0093
# L1_loss:0.3161
# Discriminator_loss:0.7706
#
# EPOCH[3] - STEP[190]
# Generator_loss:4.1586
# L1_loss:0.2181
# Discriminator_loss:0.9307
#
# EPOCH[3] - STEP[200]
# Generator_loss:0.5766
# L1_loss:0.2860
# Discriminator_loss:1.0804
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.6567
# L1_loss:0.2843
# Discriminator_loss:0.5499
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.2741
# L1_loss:0.2447
# Discriminator_loss:0.6983
#
# EPOCH[4] - STEP[30]
# Generator_loss:0.3642
# L1_loss:0.2552
# Discriminator_loss:1.6454
#
# EPOCH[4] - STEP[40]
# Generator_loss:0.3893
# L1_loss:0.2442
# Discriminator_loss:1.4199
#
# EPOCH[4] - STEP[50]
# Generator_loss:2.3687
# L1_loss:0.2924
# Discriminator_loss:0.1805
#
# EPOCH[4] - STEP[60]
# Generator_loss:0.6398
# L1_loss:0.2789
# Discriminator_loss:1.1005
#
# EPOCH[4] - STEP[70]
# Generator_loss:2.7803
# L1_loss:0.2339
# Discriminator_loss:0.5163
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.6385
# L1_loss:0.2374
# Discriminator_loss:0.3351
#
# EPOCH[4] - STEP[90]
# Generator_loss:1.4689
# L1_loss:0.2600
# Discriminator_loss:2.2633
#
# EPOCH[4] - STEP[100]
# Generator_loss:2.6222
# L1_loss:0.2452
# Discriminator_loss:0.2578
#
# EPOCH[4] - STEP[110]
# Generator_loss:2.1177
# L1_loss:0.3364
# Discriminator_loss:0.3522
#
# EPOCH[4] - STEP[120]
# Generator_loss:2.6912
# L1_loss:0.2968
# Discriminator_loss:0.5938
#
# EPOCH[4] - STEP[130]
# Generator_loss:1.1238
# L1_loss:0.2570
# Discriminator_loss:0.6048
#
# EPOCH[4] - STEP[140]
# Generator_loss:2.3390
# L1_loss:0.2685
# Discriminator_loss:0.3463
#
# EPOCH[4] - STEP[150]
# Generator_loss:1.6840
# L1_loss:0.2371
# Discriminator_loss:0.5389
#
# EPOCH[4] - STEP[160]
# Generator_loss:0.5648
# L1_loss:0.2279
# Discriminator_loss:1.3704
#
# EPOCH[4] - STEP[170]
# Generator_loss:3.1880
# L1_loss:0.2555
# Discriminator_loss:0.4727
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.1553
# L1_loss:0.2207
# Discriminator_loss:1.3303
#
# EPOCH[4] - STEP[190]
# Generator_loss:2.9471
# L1_loss:0.2621
# Discriminator_loss:0.4075
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.2617
# L1_loss:0.2420
# Discriminator_loss:0.6606
#
# EPOCH[5] - STEP[10]
# Generator_loss:0.4460
# L1_loss:0.2713
# Discriminator_loss:1.2990
#
# EPOCH[5] - STEP[20]
# Generator_loss:0.5529
# L1_loss:0.2265
# Discriminator_loss:1.1265
#
# EPOCH[5] - STEP[30]
# Generator_loss:0.1459
# L1_loss:0.2612
# Discriminator_loss:2.2332
#
# EPOCH[5] - STEP[40]
# Generator_loss:0.5729
# L1_loss:0.2059
# Discriminator_loss:1.0900
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.9571
# L1_loss:0.3053
# Discriminator_loss:0.2897
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.9709
# L1_loss:0.3258
# Discriminator_loss:0.2717
#
# EPOCH[5] - STEP[70]
# Generator_loss:0.8574
# L1_loss:0.2345
# Discriminator_loss:0.7279
#
# EPOCH[5] - STEP[80]
# Generator_loss:2.1239
# L1_loss:0.2540
# Discriminator_loss:0.3900
#
# EPOCH[5] - STEP[90]
# Generator_loss:2.4253
# L1_loss:0.2444
# Discriminator_loss:0.3837
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.7441
# L1_loss:0.3091
# Discriminator_loss:0.1506
#
# EPOCH[5] - STEP[110]
# Generator_loss:1.2815
# L1_loss:0.2369
# Discriminator_loss:1.4662
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.2634
# L1_loss:0.2070
# Discriminator_loss:0.4440
#
# EPOCH[5] - STEP[130]
# Generator_loss:2.1446
# L1_loss:0.2056
# Discriminator_loss:1.7955
#
# EPOCH[5] - STEP[140]
# Generator_loss:2.2132
# L1_loss:0.2475
# Discriminator_loss:0.6905
#
# EPOCH[5] - STEP[150]
# Generator_loss:1.5505
# L1_loss:0.1955
# Discriminator_loss:1.5484
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.0630
# L1_loss:0.2093
# Discriminator_loss:0.5786
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.7502
# L1_loss:0.2651
# Discriminator_loss:0.2188
#
# EPOCH[5] - STEP[180]
# Generator_loss:0.2237
# L1_loss:0.2635
# Discriminator_loss:1.8281
#
# EPOCH[5] - STEP[190]
# Generator_loss:1.4842
# L1_loss:0.2290
# Discriminator_loss:0.3265
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.2701
# L1_loss:0.2533
# Discriminator_loss:1.1141
#
# EPOCH[6] - STEP[10]
# Generator_loss:2.6784
# L1_loss:0.3107
# Discriminator_loss:0.1311
#
# EPOCH[6] - STEP[20]
# Generator_loss:2.2466
# L1_loss:0.2140
# Discriminator_loss:0.7817
#
# EPOCH[6] - STEP[30]
# Generator_loss:1.1746
# L1_loss:0.2414
# Discriminator_loss:0.5864
#
# EPOCH[6] - STEP[40]
# Generator_loss:1.6992
# L1_loss:0.2364
# Discriminator_loss:0.4302
#
# EPOCH[6] - STEP[50]
# Generator_loss:0.5937
# L1_loss:0.2539
# Discriminator_loss:1.0968
#
# EPOCH[6] - STEP[60]
# Generator_loss:2.6498
# L1_loss:0.3034
# Discriminator_loss:0.3014
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.2503
# L1_loss:0.2767
# Discriminator_loss:0.5040
#
# EPOCH[6] - STEP[80]
# Generator_loss:0.8884
# L1_loss:0.2299
# Discriminator_loss:0.7067
#
# EPOCH[6] - STEP[90]
# Generator_loss:0.5819
# L1_loss:0.2440
# Discriminator_loss:1.3168
#
# EPOCH[6] - STEP[100]
# Generator_loss:2.7472
# L1_loss:0.2349
# Discriminator_loss:0.0951
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.3432
# L1_loss:0.2646
# Discriminator_loss:0.4769
#
# EPOCH[6] - STEP[120]
# Generator_loss:0.2330
# L1_loss:0.2201
# Discriminator_loss:1.9020
# EPOCH[6] - STEP[130]
# Generator_loss:1.7282
# L1_loss:0.2667
# Discriminator_loss:0.2765
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.7412
# L1_loss:0.2964
# Discriminator_loss:0.6847
#
# EPOCH[6] - STEP[150]
# Generator_loss:0.6193
# L1_loss:0.2499
# Discriminator_loss:1.6018
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.7338
# L1_loss:0.2074
# Discriminator_loss:1.0778
#
# EPOCH[6] - STEP[170]
# Generator_loss:0.7053
# L1_loss:0.2750
# Discriminator_loss:0.9666
#
# EPOCH[6] - STEP[180]
# Generator_loss:3.1515
# L1_loss:0.2415
# Discriminator_loss:0.8872
#
# EPOCH[6] - STEP[190]
# Generator_loss:2.6936
# L1_loss:0.2235
# Discriminator_loss:0.3168
#
# EPOCH[6] - STEP[200]
# Generator_loss:0.4918
# L1_loss:0.2755
# Discriminator_loss:1.1414
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.4941
# L1_loss:0.2535
# Discriminator_loss:0.9855
#
# EPOCH[7] - STEP[20]
# Generator_loss:3.4332
# L1_loss:0.2678
# Discriminator_loss:0.1081
#
# EPOCH[7] - STEP[30]
# Generator_loss:1.5272
# L1_loss:0.2344
# Discriminator_loss:0.5038
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.8530
# L1_loss:0.2660
# Discriminator_loss:0.0971
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.0668
# L1_loss:0.3078
# Discriminator_loss:0.3436
#
# EPOCH[7] - STEP[60]
# Generator_loss:4.0214
# L1_loss:0.2704
# Discriminator_loss:0.5451
#
# EPOCH[7] - STEP[70]
# Generator_loss:0.2227
# L1_loss:0.2345
# Discriminator_loss:1.7973
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.8330
# L1_loss:0.3210
# Discriminator_loss:0.3266
#
# EPOCH[7] - STEP[90]
# Generator_loss:2.2480
# L1_loss:0.2890
# Discriminator_loss:1.1271
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.3405
# L1_loss:0.2297
# Discriminator_loss:0.6589
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.4619
# L1_loss:0.2245
# Discriminator_loss:0.4908
#
# EPOCH[7] - STEP[120]
# Generator_loss:2.1346
# L1_loss:0.2396
# Discriminator_loss:0.2247
#
# EPOCH[7] - STEP[130]
# Generator_loss:1.1891
# L1_loss:0.2269
# Discriminator_loss:0.6430
#
# EPOCH[7] - STEP[140]
# Generator_loss:2.4301
# L1_loss:0.2516
# Discriminator_loss:0.3232
#
# EPOCH[7] - STEP[150]
# Generator_loss:2.6076
# L1_loss:0.2572
# Discriminator_loss:0.4195
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.2156
# L1_loss:0.2042
# Discriminator_loss:0.6780
#
# EPOCH[7] - STEP[170]
# Generator_loss:3.0860
# L1_loss:0.2326
# Discriminator_loss:0.1554
#
# EPOCH[7] - STEP[180]
# Generator_loss:2.4522
# L1_loss:0.1919
# Discriminator_loss:0.9365
#
# EPOCH[7] - STEP[190]
# Generator_loss:1.4644
# L1_loss:0.2662
# Discriminator_loss:0.3226
#
# EPOCH[7] - STEP[200]
# Generator_loss:4.2152
# L1_loss:0.2754
# Discriminator_loss:0.9931
#
# EPOCH[8] - STEP[10]
# Generator_loss:1.5810
# L1_loss:0.2535
# Discriminator_loss:0.3929
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.6881
# L1_loss:0.2563
# Discriminator_loss:0.3359
#
# EPOCH[8] - STEP[30]
# Generator_loss:1.5205
# L1_loss:0.2373
# Discriminator_loss:0.3667
#
# EPOCH[8] - STEP[40]
# Generator_loss:2.3439
# L1_loss:0.2266
# Discriminator_loss:0.8711
#
# EPOCH[8] - STEP[50]
# Generator_loss:2.7079
# L1_loss:0.2913
# Discriminator_loss:0.7334
#
# EPOCH[8] - STEP[60]
# Generator_loss:2.6440
# L1_loss:0.3294
# Discriminator_loss:0.1695
#
# EPOCH[8] - STEP[70]
# Generator_loss:1.4892
# L1_loss:0.2576
# Discriminator_loss:0.8730
#
# EPOCH[8] - STEP[80]
# Generator_loss:3.5467
# L1_loss:0.2639
# Discriminator_loss:0.0836
#
# EPOCH[8] - STEP[90]
# Generator_loss:1.8986
# L1_loss:0.2464
# Discriminator_loss:0.2814
#
# EPOCH[8] - STEP[100]
# Generator_loss:0.5917
# L1_loss:0.2341
# Discriminator_loss:0.9443
#
# EPOCH[8] - STEP[110]
# Generator_loss:3.1181
# L1_loss:0.2576
# Discriminator_loss:0.6137
#
# EPOCH[8] - STEP[120]
# Generator_loss:3.4553
# L1_loss:0.2902
# Discriminator_loss:0.1021
#
# EPOCH[8] - STEP[130]
# Generator_loss:0.7085
# L1_loss:0.1946
# Discriminator_loss:1.4852
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.6645
# L1_loss:0.2166
# Discriminator_loss:1.1447
#
# EPOCH[8] - STEP[150]
# Generator_loss:0.8741
# L1_loss:0.2087
# Discriminator_loss:0.7363
#
# EPOCH[8] - STEP[160]
# Generator_loss:3.5448
# L1_loss:0.2217
# Discriminator_loss:1.0135
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.8466
# L1_loss:0.2262
# Discriminator_loss:0.4906
#
# EPOCH[8] - STEP[180]
# Generator_loss:0.8359
# L1_loss:0.2188
# Discriminator_loss:0.9106
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.5434
# L1_loss:0.2512
# Discriminator_loss:0.4028
#
# EPOCH[8] - STEP[200]
# Generator_loss:4.8152
# L1_loss:0.2551
# Discriminator_loss:2.7509
#
# EPOCH[9] - STEP[10]
# Generator_loss:0.9202
# L1_loss:0.2241
# Discriminator_loss:0.9714
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.3316
# L1_loss:0.2820
# Discriminator_loss:0.4986
#
# EPOCH[9] - STEP[30]
# Generator_loss:0.8074
# L1_loss:0.2378
# Discriminator_loss:0.8397
#
# EPOCH[9] - STEP[40]
# Generator_loss:0.7115
# L1_loss:0.2440
# Discriminator_loss:1.2199
#
# EPOCH[9] - STEP[50]
# Generator_loss:2.1812
# L1_loss:0.2322
# Discriminator_loss:0.1883
#
# EPOCH[9] - STEP[60]
# Generator_loss:0.8083
# L1_loss:0.1843
# Discriminator_loss:0.7022
#
# EPOCH[9] - STEP[70]
# Generator_loss:2.3704
# L1_loss:0.2791
# Discriminator_loss:0.2127
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.8671
# L1_loss:0.2388
# Discriminator_loss:0.3406
# EPOCH[9] - STEP[90]
# Generator_loss:1.9547
# L1_loss:0.2161
# Discriminator_loss:1.4829
#
# EPOCH[9] - STEP[100]
# Generator_loss:0.9063
# L1_loss:0.2305
# Discriminator_loss:0.7480
#
# EPOCH[9] - STEP[110]
# Generator_loss:1.9519
# L1_loss:0.3445
# Discriminator_loss:0.2522
#
# EPOCH[9] - STEP[120]
# Generator_loss:0.4956
# L1_loss:0.2265
# Discriminator_loss:1.1595
#
# EPOCH[9] - STEP[130]
# Generator_loss:2.5008
# L1_loss:0.2494
# Discriminator_loss:0.3086
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.3797
# L1_loss:0.2368
# Discriminator_loss:0.4200
#
# EPOCH[9] - STEP[150]
# Generator_loss:1.5297
# L1_loss:0.2320
# Discriminator_loss:0.4092
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.8175
# L1_loss:0.2261
# Discriminator_loss:0.4313
#
# EPOCH[9] - STEP[170]
# Generator_loss:2.2026
# L1_loss:0.2852
# Discriminator_loss:1.4546
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.9902
# L1_loss:0.2521
# Discriminator_loss:0.2327
#
# EPOCH[9] - STEP[190]
# Generator_loss:0.4359
# L1_loss:0.3192
# Discriminator_loss:1.2643
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.7653
# L1_loss:0.2197
# Discriminator_loss:0.5778
#
# EPOCH[10] - STEP[10]
# Generator_loss:2.0940
# L1_loss:0.2399
# Discriminator_loss:0.4415
#
# EPOCH[10] - STEP[20]
# Generator_loss:0.5870
# L1_loss:0.2157
# Discriminator_loss:0.9314
#
# EPOCH[10] - STEP[30]
# Generator_loss:1.2711
# L1_loss:0.2325
# Discriminator_loss:0.6137
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.9621
# L1_loss:0.2481
# Discriminator_loss:1.0285
#
# EPOCH[10] - STEP[50]
# Generator_loss:3.6216
# L1_loss:0.2580
# Discriminator_loss:0.4214
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.4589
# L1_loss:0.2818
# Discriminator_loss:0.3342
#
# EPOCH[10] - STEP[70]
# Generator_loss:1.5489
# L1_loss:0.2317
# Discriminator_loss:0.3714
#
# EPOCH[10] - STEP[80]
# Generator_loss:1.5878
# L1_loss:0.2542
# Discriminator_loss:0.4054
#
# EPOCH[10] - STEP[90]
# Generator_loss:1.8103
# L1_loss:0.2588
# Discriminator_loss:1.6321
#
# EPOCH[10] - STEP[100]
# Generator_loss:1.1009
# L1_loss:0.2355
# Discriminator_loss:0.6197
#
# EPOCH[10] - STEP[110]
# Generator_loss:3.0491
# L1_loss:0.2575
# Discriminator_loss:0.1457
#
# EPOCH[10] - STEP[120]
# Generator_loss:2.3784
# L1_loss:0.2554
# Discriminator_loss:0.6099
#
# EPOCH[10] - STEP[130]
# Generator_loss:3.6397
# L1_loss:0.2269
# Discriminator_loss:0.8819
#
# EPOCH[10] - STEP[140]
# Generator_loss:0.0756
# L1_loss:0.2587
# Discriminator_loss:3.0544
#
# EPOCH[10] - STEP[150]
# Generator_loss:3.6146
# L1_loss:0.2962
# Discriminator_loss:0.0798
#
# EPOCH[10] - STEP[160]
# Generator_loss:3.3289
# L1_loss:0.2290
# Discriminator_loss:0.3688
#
# EPOCH[10] - STEP[170]
# Generator_loss:1.7192
# L1_loss:0.3140
# Discriminator_loss:0.4666
#
# EPOCH[10] - STEP[180]
# Generator_loss:3.4251
# L1_loss:0.2439
# Discriminator_loss:0.1580
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.7913
# L1_loss:0.2257
# Discriminator_loss:0.3585
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.2467
# L1_loss:0.2160
# Discriminator_loss:0.6328

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
